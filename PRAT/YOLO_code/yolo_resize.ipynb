# %%
from ultralytics import YOLO
import torch
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, Image
import matplotlib.patches as patches
import os

# %%
Model = YOLO("yolov8x.pt")
# Out:
# ...
#   0%|          | 0.00/131M [00:00<?, ?B/s]

# %%
if torch.cuda.is_available():
    Model = Model.to('cuda')

# %%
Model.train(data='data_resize.yaml', epochs=300, batch = 32, imgsz = 1280, patience=300, optimizer = 'AdamW', lr0 = 0.00000001)
# Out:
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
Model_continue = YOLO("runs/detect/train2/weights/last.pt")

# %%
Model_continue.train(resume = True)
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.9.2 torch-1.10.1+cu113 CUDA:0 (NVIDIA A100 80GB PCIe, 81070MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
Image(filename = 'runs/detect/train2/confusion_matrix.png',width = 600)

# %%
Image(filename = 'runs/detect/train2/results.png',width = 600)

# %%
test_set = ['2ec3f1bb9','3589adb90','d488c759a','aa05346ff','57512b7f1']
path = 'dataset_resize_5/images/test/'

# %%
model_test = YOLO("runs/detect/train2/weights/best.pt")
for image_id in test_set:
    rest_path = os.path.join(path, f"{image_id}.png")
    results = model_test.predict(rest_path)
    
    for result in results:
        orig_img = result.orig_img
        boxes = result.boxes
        
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    res_plotted = results[0].plot()
    axs[0].imshow(res_plotted)
    axs[0].set_title('Result Plot')


    axs[1].imshow(orig_img) 
    axs[1].set_title('Boxes Plot')


    for i, box in enumerate(boxes.xyxy):
        x1 = box[0].item()
        y1 = box[1].item()
        x2 = box[2].item()
        y2 = box[3].item()
        width, height = x2 - x1, y2 - y1
        rect = patches.Rectangle((x1, y1), width, height, linewidth=1, edgecolor='r', facecolor='none')
        axs[1].add_patch(rect)

    plt.tight_layout()  
    plt.show()
# Out:
# image 1/1 /users/nfs/Etu3/21210063/dataset_resize_5/images/test/2ec3f1bb9.png: 672x1280 123 glomerulis, 36.2ms
# Speed: 16.5ms preprocess, 36.2ms inference, 3.0ms postprocess per image at shape (1, 3, 672, 1280)
# image 1/1 /users/nfs/Etu3/21210063/dataset_resize_5/images/test/3589adb90.png: 1280x992 244 glomerulis, 26.2ms
# Speed: 10.8ms preprocess, 26.2ms inference, 1.6ms postprocess per image at shape (1, 3, 1280, 992)
# image 1/1 /users/nfs/Etu3/21210063/dataset_resize_5/images/test/d488c759a.png: 1280x800 142 glomerulis, 26.5ms
# Speed: 11.1ms preprocess, 26.5ms inference, 1.5ms postprocess per image at shape (1, 3, 1280, 800)
# image 1/1 /users/nfs/Etu3/21210063/dataset_resize_5/images/test/aa05346ff.png: 832x1280 267 glomerulis, 26.5ms
# Speed: 11.1ms preprocess, 26.5ms inference, 1.5ms postprocess per image at shape (1, 3, 832, 1280)
# image 1/1 /users/nfs/Etu3/21210063/dataset_resize_5/images/test/57512b7f1.png: 992x1280 183 glomerulis, 35.4ms
# ...
